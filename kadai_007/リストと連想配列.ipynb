# %%
# 曜日別の天気のリスト
array = ["月曜日は晴れです", "火曜日は雨です", "水曜日は晴れです",
         "木曜日は晴れです", "金曜日は曇りです",
         "土曜日は曇りのうち雨です", "日曜日は雷雨です"]

print(array[3])  # 木曜日

# ディクショナリ
dictionary = {
    "mon": "晴れ",
    "tue": "雨",
    "wed": "晴れ",
    "thu": "晴れ",
    "fri": "曇り",
    "sat": "曇りのうち晴れ",
    "sun": "雷雨"
}

print(dictionary["mon"])  # 晴れ
# Out:
# 木曜日は晴れです
# 晴れ

# %%
# 曜日別の天気のリスト
array = ["月曜日は晴れです", "火曜日は雨です", "水曜日は晴れです",
         "木曜日は晴れです", "金曜日は曇りです",
         "土曜日は曇りのうち雨です", "日曜日は雷雨です"]

print(array[3])  # 木曜日

# ディクショナリ
dictionary = {mon: "晴れ",tue: "雨",wed: "晴れ",thu: "晴れ",fri: "曇り",sat: "曇りのうち晴れ",sun: "雷雨"}

print(dictionary[mon])  # 晴れ

# %%
# 曜日別の天気のリスト
array = ["月曜日は晴れです", "火曜日は雨です", "水曜日は晴れです",
         "木曜日は晴れです", "金曜日は曇りです",
         "土曜日は曇りのうち雨です", "日曜日は雷雨です"]

print(array[3])  # 木曜日

# ディクショナリ
dictionary = {1: "晴れ",2: "雨",3: "晴れ",4: "晴れ",5: "曇り",6: "曇りのうち晴れ",7: "雷雨"}

print(dictionary[1])  # 晴れ
# Out:
# 木曜日は晴れです
# 晴れ
